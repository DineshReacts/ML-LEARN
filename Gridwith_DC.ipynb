# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshReacts/ML-LEARN/blob/main/Gridwith_DC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10],
    'min_weight_fraction_leaf': [0.0, 0.05],
    'max_features': ['sqrt', 'log2'],
    'max_leaf_nodes': [None, 30, 50],
    'random_state': [42],
    'min_impurity_decrease': [0.0, 0.01],
    'class_weight': [None, 'balanced'],
    'ccp_alpha': [0.0, 0.01],
    'monotonic_cst': [None]  # Example; specific use case dependent, often left out of generic grids
}

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20736 candidates, totalling 103680 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'ccp_alpha': [0.0, 0.01],
#                          'class_weight': [None, 'balanced'],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'max_leaf_nodes': [None, 30, 50],
#                          'min_impurity_decrease': [0.0, 0.01],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 10, 20],
#                          'min_weight_fraction_leaf': [0.0, 0.05],
#                          'monotonic_cst': [None], 'random_state': [42],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
# print classification report
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'ccp_alpha': 0.01, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 30, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'random'}: 0.9023809523809525

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[52  6]
#  [ 2 20]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        58
#            1       0.77      0.91      0.83        22
#
#     accuracy                           0.90        80
#    macro avg       0.87      0.90      0.88        80
# weighted avg       0.91      0.90      0.90        80

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9181034482758621)

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#        mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0.003872      0.000804         0.005792        0.001429
# 1           0.003243      0.000440         0.004550        0.000135
# 2           0.003005      0.000094         0.004670        0.000273
# 3           0.003026      0.000489         0.004730        0.000413
# 4           0.003394      0.000994         0.004520        0.000074
# ...              ...           ...              ...             ...
# 20731       0.004143      0.000614         0.004836        0.000739
# 20732       0.003851      0.000033         0.004781        0.000610
# 20733       0.003645      0.000053         0.004762        0.000632
# 20734       0.004182      0.000740         0.005336        0.001397
# 20735       0.003109      0.000608         0.003722        0.000840
#
#        param_ccp_alpha param_class_weight param_criterion param_max_depth  \
# 0                 0.00               None            gini            None
# 1                 0.00               None            gini            None
# 2                 0.00               None            gini            None
# 3                 0.00               None            gini            None
# 4                 0.00               None            gini            None
# ...                ...                ...             ...             ...
# 20731             0.01           balanced        log_loss              30
# 20732             0.01           balanced        log_loss              30
# 20733             0.01           balanced        log_loss              30
# 20734             0.01           balanced        log_loss              30
# 20735             0.01           balanced        log_loss              30
#
#       param_max_features param_max_leaf_nodes  ...  param_splitter  \
# 0                   sqrt                 None  ...            best
# 1                   sqrt                 None  ...          random
# 2                   sqrt                 None  ...            best
# 3                   sqrt                 None  ...          random
# 4                   sqrt                 None  ...            best
# ...                  ...                  ...  ...             ...
# 20731               log2                   50  ...          random
# 20732               log2                   50  ...            best
# 20733               log2                   50  ...          random
# 20734               log2                   50  ...            best
# 20735               log2                   50  ...          random
#
#                                                   params  split0_test_score  \
# 0      {'ccp_alpha': 0.0, 'class_weight': None, 'crit...           0.797547
# 1      {'ccp_alpha': 0.0, 'class_weight': None, 'crit...           0.844699
# 2      {'ccp_alpha': 0.0, 'class_weight': None, 'crit...           0.827459
# 3      {'ccp_alpha': 0.0, 'class_weight': None, 'crit...           0.780782
# 4      {'ccp_alpha': 0.0, 'class_weight': None, 'crit...           0.810937
# ...                                                  ...                ...
# 20731  {'ccp_alpha': 0.01, 'class_weight': 'balanced'...           0.689723
# 20732  {'ccp_alpha': 0.01, 'class_weight': 'balanced'...           0.737352
# 20733  {'ccp_alpha': 0.01, 'class_weight': 'balanced'...           0.689723
# 20734  {'ccp_alpha': 0.01, 'class_weight': 'balanced'...           0.737352
# 20735  {'ccp_alpha': 0.01, 'class_weight': 'balanced'...           0.689723
#
#        split1_test_score split2_test_score  split3_test_score  \
# 0               0.795968          0.843750           0.830822
# 1               0.842259          0.830503           0.875897
# 2               0.813846          0.890137           0.859920
# 3               0.840368          0.724638           0.842259
# 4               0.875000          0.842259           0.906923
# ...                  ...               ...                ...
# 20731           0.717156          0.610658           0.724638
# 20732           0.842259          0.738050           0.691176
# 20733           0.717156          0.610658           0.724638
# 20734           0.842259          0.738050           0.691176
# 20735           0.717156          0.610658           0.724638
#
#       split4_test_score mean_test_score  std_test_score  rank_test_score
# 0              0.791040        0.811825        0.021295             8783
# 1              0.857229        0.850117        0.015434             5263
# 2              0.870432        0.852359        0.027979             5039
# 3              0.816984        0.801006        0.044153             9185
# 4              0.870432        0.861110        0.032408             1763
# ...                 ...             ...             ...              ...
# 20731          0.647739        0.677983        0.043119            17537
# 20732          0.707233        0.743214        0.052675            15265
# 20733          0.647739        0.677983        0.043119            17537
# 20734          0.707233        0.743214        0.052675            15265
# 20735          0.647739        0.677983        0.043119            17537
#
# [20736 rows x 26 columns]
